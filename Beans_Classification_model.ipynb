# %%
#Loading the datasets
import pandas as pd
beans_data=pd.read_excel('Dry_Bean_Dataset.xlsx')

# %%
beans_data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
beans_data.shape
# Out:
# (13611, 17)

# %%
beans_data.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
beans_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.pairplot(beans_data)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(beans_data.corr(),annot=True)

# %%
plt.figure(figsize=(32,18))
sns.catplot(data=beans_data,x='Class',y='ShapeFactor1')

# %%
plt.figure(figsize=(32,18))
sns.catplot(data=beans_data,x='Class',y='ShapeFactor2')

# %%
plt.figure(figsize=(32,18))
sns.catplot(data=beans_data,x='Class',y='ShapeFactor3')

# %%
plt.figure(figsize=(32,18))
sns.catplot(data=beans_data,x='Class',y='ShapeFactor4')

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
beans_data['Class']=label.fit_transform(beans_data['Class'])

# %%
x=beans_data.drop('Class',axis=1)
y=beans_data['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
y_train
# Out:
# 11215    3
# 3612     1
# 12723    3
# 8011     6
# 899      5
#         ..
# 905      5
# 5192     2
# 12172    3
# 235      5
# 13349    3
# Name: Class, Length: 10208, dtype: int64

# %%
y_test
# Out:
# 10057    6
# 13354    3
# 13141    3
# 8634     6
# 12579    3
#         ..
# 10910    3
# 1647     5
# 7175     4
# 9217     6
# 8662     6
# Name: Class, Length: 3403, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test=scale.transform(x_test)

# %%
x_train
# Out:
# array([[-0.79896243, -1.00173638, -0.98436662, ...,  0.91657138,
#          0.35605695,  0.63700475],
#        [ 4.04442655,  3.16667974,  2.70580537, ..., -1.16955689,
#          0.74045879,  0.3269182 ],
#        [-0.59678094, -0.77611416, -0.88624898, ...,  1.22134128,
#          1.17062194,  0.09094049],
#        ...,
#        [-0.6772444 , -0.85176898, -0.82569455, ...,  0.71473882,
#          0.36640624,  0.73227237],
#        [-0.62763663, -0.87249448, -1.0934843 , ...,  2.13430666,
#          2.19512159,  0.87838739],
#        [-0.46960775, -0.55215109, -0.4912581 , ...,  0.18845638,
#          0.03575421,  0.46536198]])

# %%
x_test
# Out:
# array([[ 0.15545015,  0.28717793,  0.46870282, ..., -0.81383925,
#         -0.79428404, -0.17833354],
#        [-0.46841444, -0.54592459, -0.46749239, ...,  0.12459114,
#         -0.05329731,  0.76857206],
#        [-0.51727213, -0.62863549, -0.59944997, ...,  0.3966008 ,
#          0.2459835 ,  0.11773891],
#        ...,
#        [ 0.28869218,  0.65257958,  1.18732948, ..., -1.50691405,
#         -2.05744192,  0.6862797 ],
#        [-0.21573871, -0.11967937, -0.1434362 , ..., -0.19176524,
#         -0.15928635, -0.34776837],
#        [-0.30278245, -0.26742835, -0.2491859 , ..., -0.1000309 ,
#         -0.13622234,  0.05387033]])

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(solver='lbfgs', max_iter=3000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.9241845430502498

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.89920658242727

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.9282985600940347

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.9291801351748458
